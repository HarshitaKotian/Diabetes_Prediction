# %%
import seaborn as sb
import pandas as pd
from sklearn import preprocessing as pp
dataset=pd.read_csv("diabetes.csv")
encoder=pp.LabelEncoder()
dataset["Outcome"]=encoder.fit_transform(dataset["Outcome"])
sb.boxplot(data=dataset["BloodPressure"]).set(title="Box Plot")
# Out:
# [Text(0.5,1,'Box Plot')]

# %%
dataset["BloodPressure"].describe()
# Out:
# count    768.000000
# mean      69.105469
# std       19.355807
# min        0.000000
# 25%       62.000000
# 50%       72.000000
# 75%       80.000000
# max      122.000000
# Name: BloodPressure, dtype: float64

# %% [markdown]
# # FORMULAS USED

# %%
q1=62
q3=80
IQR=q3-q1
IQR
# Out:
# 18

# %%
lowerlimit=q1-1.5*IQR
lowerlimit
# Out:
# 35.0

# %%
upperlimit=q3+1.5*IQR
upperlimit
# Out:
# 107.0

# %%
dataset["BloodPressure"]
dataset_iqr=dataset[(dataset["BloodPressure"]>lowerlimit) & (dataset["BloodPressure"]<upperlimit)]

# %%
dataset_iqr;

# %%
sb.boxplot(data=dataset_iqr["BloodPressure"]).set(title="Box Plot")

# %%
sb.boxplot(data=dataset["BMI"]).set(title="Box Plot")
# Out:
# [Text(0.5,1,'Box Plot')]

# %%
dataset["BMI"].describe()
# Out:
# count    768.000000
# mean      31.992578
# std        7.884160
# min        0.000000
# 25%       27.300000
# 50%       32.000000
# 75%       36.600000
# max       67.100000
# Name: BMI, dtype: float64

# %%
a1=27.300000
a3=36.600000
IQr=q3-q1
Upperlimit=a3+1.5*IQr
Lowerlimit=a1-1.5*IQr
Upperlimit
# Out:
# 50.550000000000004

# %%
Lowerlimit
# Out:
# 13.35

# %%
dataset["BMI"]
dataset=dataset[(dataset["BMI"]>lowerlimit) & (dataset["BMI"]<upperlimit)]

# %%
dataset["BMI"]
# Out:
# 4      43.1
# 7      35.3
# 10     37.6
# 11     38.0
# 16     45.8
# 18     43.3
# 20     39.3
# 21     35.4
# 22     39.8
# 24     36.6
# 26     39.4
# 30     36.0
# 38     38.2
# 39     37.1
# 41     40.2
# 43     45.4
# 45     42.0
# 48     39.1
# 56     37.7
# 57     46.8
# 58     40.5
# 59     41.5
# 67     42.7
# 72     43.4
# 73     35.1
# 77     37.7
# 78     43.2
# 84     48.8
# 86     36.6
# 87     38.5
#        ...
# 693    38.5
# 699    44.5
# 700    35.9
# 703    38.5
# 705    39.8
# 709    38.0
# 712    41.2
# 718    35.5
# 719    35.6
# 721    38.1
# 723    39.1
# 725    39.4
# 726    36.1
# 732    44.5
# 735    35.4
# 738    36.6
# 739    39.5
# 740    42.3
# 744    40.6
# 746    49.3
# 747    46.3
# 748    36.4
# 751    39.0
# 753    43.3
# 755    36.5
# 757    36.3
# 758    37.5
# 759    35.5
# 761    44.0
# 764    36.8
# Name: BMI, Length: 244, dtype: float64

# %%
sb.boxplot(data=dataset["BMI"]).set(title="BOX")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-73-bb6d6755d403> in <module>
# ----> 1 sb.boxplot(data=dataset["BMI"]).set(title="BOX")
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, notch, ax, **kwargs)
#    2229     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2230                           orient, color, palette, saturation,
# -> 2231                           width, dodge, fliersize, linewidth)
#    2232
#    2233     if ax is None:
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth)
#     444                  width, dodge, fliersize, linewidth):
#     445
# ...

# %%
dataset["Age"].describe()
# Out:
# count    244.000000
# mean      33.586066
# std       10.696562
# min       21.000000
# 25%       25.000000
# 50%       29.000000
# 75%       41.000000
# max       68.000000
# Name: Age, dtype: float64

# %%
b1=21
b3=41
iqr=b3-b1
iqr
# Out:
# 20

# %%
Upper=b3+1.5*iqr
Upper
# Out:
# 71.0

# %%
lower=b1-1.5*iqr
lower
# Out:
# -9.0

# %%
sb.boxplot(data=dataset["Age"]).set(title="Box")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-79-d2a772fa1597> in <module>
# ----> 1 sb.boxplot(data=dataset["Age"]).set(title="Box")
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, notch, ax, **kwargs)
#    2229     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2230                           orient, color, palette, saturation,
# -> 2231                           width, dodge, fliersize, linewidth)
#    2232
#    2233     if ax is None:
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth)
#     444                  width, dodge, fliersize, linewidth):
#     445
# ...

# %%
dataset
# Out:
#      Pregnancies  Glucose  BloodPressure  skinThickness  Insulin   BMI  \
# 4              0    137.0             40             35      168  43.1
# 7             10    115.0              0              0        0  35.3
# 10             4    110.0             92              0        0  37.6
# 11            10    168.0             74              0        0  38.0
# 16             0    118.0             84             47      230  45.8
# 18             1    103.0             30             38       83  43.3
# 20             3    126.0             88             41      235  39.3
# 21             8     99.0             84              0        0  35.4
# 22             7    196.0             90              0        0  39.8
# 24            11    143.0             94             33      146  36.6
# 26             7    147.0             76              0        0  39.4
# 30             5    109.0             75             26        0  36.0
# ...

# %%
sb.boxplot(data=dataset["Age"]).set(title="Box")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-81-d2a772fa1597> in <module>
# ----> 1 sb.boxplot(data=dataset["Age"]).set(title="Box")
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, notch, ax, **kwargs)
#    2229     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2230                           orient, color, palette, saturation,
# -> 2231                           width, dodge, fliersize, linewidth)
#    2232
#    2233     if ax is None:
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth)
#     444                  width, dodge, fliersize, linewidth):
#     445
# ...
